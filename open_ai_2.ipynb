# %%
from openai import OpenAI
from datetime import datetime
from pydantic import BaseModel
from typing import List
import json
import yaml
import pandas as pd
import textwrap

# %%
# Load API key from config file
with open('config.yaml', 'r') as f:
    config = yaml.safe_load(f)
    api_key = config['api_key']

client = OpenAI(api_key=api_key)

# %%
class ExtractResponse(BaseModel):
    representative_quotes: List[str]
    quantitative_summary: List[str]
    qualitative_summary: List[str]

# %%
def detect_data_or_ai(passage: str) -> int:
    prompt = f"""You are a classifier. Read the following passage and determine if the company talks
about topics related to 'data' or 'AI' (artificial intelligence), including concepts
like analytics, machine learning, algorithms, data-driven decision making, big data,
or AI applications.

Respond with ONLY a single number:
- 1 if the passage discusses AI or data in any meaningful way.
- 0 if it does not.

Passage:
\"\"\"{passage}\"\"\"
    """

    response = client.responses.create(
        model="gpt-5-mini",
        instructions="You are a strict binary classifier.",
        reasoning={"effort": "medium"},
        text={"verbosity": "high"},
        input=[
            {"role": "user", "content": prompt}
        ]
    )

    try:
        result = int(response.output_text)
        return 1 if result == 1 else 0
    except:
        return 0

# %%
def extract(passage: str) -> ExtractResponse:
    """Return representative quotes and summaries for passages about data/AI."""
    analyst_instructions = """You are an analyst focused on how companies discuss data and AI in earnings calls. Follow the provided formatting rules exactly."""

    user_prompt = textwrap.dedent(
        f"""Goal:
Identify how this earnings call excerpts talks about 'data' and 'AI'. Focus on
meaningful mentions tied to strategy, products, operations, risks, or investments.

Format:
1. Representative Quotes (short excerpts that explicitly mention 'data' or 'AI', make sure it's a direct quote and do not rephrase it).
2. Quantitative Summary: A list of bullet points (written as strings) covering non-exhaustive quantitative aspects such as:
   - Numbers, metrics, percentages, growth rates
   - Financial figures, revenue, costs, investments
   - Performance metrics, KPIs, benchmarks
   - Any measurable or numerical data related to data/AI
3. Qualitative Summary: A list of bullet points (as strings) covering non-exhaustive qualitative aspects such as:
   - Strategic direction, vision, goals
   - Product features, capabilities, innovations
   - Market positioning, competitive advantages
   - Risks, challenges, opportunities
   - Any non-numerical insights related to data/AI

Important:
- Both 'Quantitative Summary' and 'Qualitative Summary' have to be related to 'data' or 'AI'.
- If no quantitative or qualitative insights are found, return empty list.

Each summary should be a list of concise bullet point strings (3-8 bullet points each).

Passage:
\"\"\"{passage}\"\"\"""").strip()

    try:
        response: ExtractResponse = client.responses.parse(
            model="gpt-5-mini",
            instructions=analyst_instructions,
            reasoning={"effort": "medium"},
            text={"verbosity": "high"},
            input=[
                {"role": "user", "content": user_prompt},
            ],
            text_format=ExtractResponse,
        )
        return response.output_parsed

    except Exception:
        return ExtractResponse(representative_quotes=[], quantitative_summary=[], qualitative_summary=[])

# %%
def format_quotes(quotes: List[str]) -> str:
    """Return quotes formatted in "","" style."""
    cleaned = []
    for quote in quotes or []:
        cleaned_quote = " ".join(quote.split())
        if cleaned_quote:
            cleaned.append(cleaned_quote)
    if not cleaned:
        return ""
    return '"' + '","'.join(cleaned) + '"'

def process_row(row: pd.Series) -> pd.Series:
    """Run classification and extraction (if appropriate) for a single dataframe row."""
    passage = str(row.get("componenttext", "") or "")
    classification = detect_data_or_ai(passage)
    formatted_quotes = ""
    formatted_quantitative = ""
    formatted_qualitative = ""

    if classification == 1:
        extraction = extract(passage)
        formatted_quotes = format_quotes(extraction.representative_quotes)
        formatted_quantitative = format_quotes(extraction.quantitative_summary)
        formatted_qualitative = format_quotes(extraction.qualitative_summary)

    return pd.Series(
        {
            "is_data_or_ai": classification,
            "representative_quotes": formatted_quotes,
            "quantitative_summary": formatted_quantitative,
            "qualitative_summary": formatted_qualitative,
        }
    )

# %%
dataset_path = "transcripts_dataset/2024_q4_clean.csv"
df = pd.read_csv(dataset_path)
df = df.iloc[1098:1125]

# %%
df
# Out:
#      companyid      keydevid  transcriptid  \
# 1098     19691  1.904126e+09     3318005.0
# 1099     19691  1.904126e+09     3318005.0
# 1100     19691  1.904126e+09     3318005.0
# 1101     19691  1.904126e+09     3318005.0
# 1102     19691  1.904126e+09     3318005.0
# 1103     19691  1.904126e+09     3318005.0
# 1104     19691  1.904126e+09     3318005.0
# 1105     19691  1.904126e+09     3318005.0
# 1106     19691  1.904126e+09     3318005.0
# 1107     19691  1.904126e+09     3318005.0
# 1108     19691  1.904126e+09     3318005.0
# 1109     19691  1.904126e+09     3318005.0
# 1110     19691  1.904126e+09     3318005.0
# 1111     19691  1.904126e+09     3318005.0
# 1112     19691  1.904126e+09     3318005.0
# 1113     19691  1.904126e+09     3318005.0
# 1114     19691  1.904126e+09     3318005.0
# 1115     19691  1.904126e+09     3318005.0
# 1116     19691  1.904126e+09     3318005.0
# 1117     19691  1.904126e+09     3318005.0
# 1118     19691  1.904126e+09     3318005.0
# 1119     19691  1.904126e+09     3318005.0
# 1120     19691  1.904126e+09     3318005.0
# 1121     19691  1.904126e+09     3318005.0
# 1122     19691  1.904126e+09     3318005.0
# 1123     19691  1.904126e+09     3318005.0
# 1124     19691  1.904126e+09     3318005.0
#
#                                                headline mostimportantdateutc  \
# 1098  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1099  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1100  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1101  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1102  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1103  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1104  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1105  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1106  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1107  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1108  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1109  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1110  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1111  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1112  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1113  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1114  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1115  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1116  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1117  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1118  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1119  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1120  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1121  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1122  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1123  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1124  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
#
#      mostimportanttimeutc  keydeveventtypeid  \
# 1098             16:20:00               51.0
# 1099             16:20:00               51.0
# 1100             16:20:00               51.0
# 1101             16:20:00               51.0
# 1102             16:20:00               51.0
# 1103             16:20:00               51.0
# 1104             16:20:00               51.0
# 1105             16:20:00               51.0
# 1106             16:20:00               51.0
# 1107             16:20:00               51.0
# 1108             16:20:00               51.0
# 1109             16:20:00               51.0
# 1110             16:20:00               51.0
# 1111             16:20:00               51.0
# 1112             16:20:00               51.0
# 1113             16:20:00               51.0
# 1114             16:20:00               51.0
# 1115             16:20:00               51.0
# 1116             16:20:00               51.0
# 1117             16:20:00               51.0
# 1118             16:20:00               51.0
# 1119             16:20:00               51.0
# 1120             16:20:00               51.0
# 1121             16:20:00               51.0
# 1122             16:20:00               51.0
# 1123             16:20:00               51.0
# 1124             16:20:00               51.0
#
#                    keydeveventtypename          companyname  \
# 1098  Company Conference Presentations  Cisco Systems, Inc.
# 1099  Company Conference Presentations  Cisco Systems, Inc.
# 1100  Company Conference Presentations  Cisco Systems, Inc.
# 1101  Company Conference Presentations  Cisco Systems, Inc.
# 1102  Company Conference Presentations  Cisco Systems, Inc.
# 1103  Company Conference Presentations  Cisco Systems, Inc.
# 1104  Company Conference Presentations  Cisco Systems, Inc.
# 1105  Company Conference Presentations  Cisco Systems, Inc.
# 1106  Company Conference Presentations  Cisco Systems, Inc.
# 1107  Company Conference Presentations  Cisco Systems, Inc.
# 1108  Company Conference Presentations  Cisco Systems, Inc.
# 1109  Company Conference Presentations  Cisco Systems, Inc.
# 1110  Company Conference Presentations  Cisco Systems, Inc.
# 1111  Company Conference Presentations  Cisco Systems, Inc.
# 1112  Company Conference Presentations  Cisco Systems, Inc.
# 1113  Company Conference Presentations  Cisco Systems, Inc.
# 1114  Company Conference Presentations  Cisco Systems, Inc.
# 1115  Company Conference Presentations  Cisco Systems, Inc.
# 1116  Company Conference Presentations  Cisco Systems, Inc.
# 1117  Company Conference Presentations  Cisco Systems, Inc.
# 1118  Company Conference Presentations  Cisco Systems, Inc.
# 1119  Company Conference Presentations  Cisco Systems, Inc.
# 1120  Company Conference Presentations  Cisco Systems, Inc.
# 1121  Company Conference Presentations  Cisco Systems, Inc.
# 1122  Company Conference Presentations  Cisco Systems, Inc.
# 1123  Company Conference Presentations  Cisco Systems, Inc.
# 1124  Company Conference Presentations  Cisco Systems, Inc.
#
#       transcriptcollectiontypeid  ... transcriptcomponenttypename  \
# 1098                         8.0  ...                    Question
# 1099                         8.0  ...                      Answer
# 1100                         8.0  ...                    Question
# 1101                         8.0  ...                      Answer
# 1102                         8.0  ...                    Question
# 1103                         8.0  ...                      Answer
# 1104                         8.0  ...                    Question
# 1105                         8.0  ...                      Answer
# 1106                         8.0  ...                    Question
# 1107                         8.0  ...                      Answer
# 1108                         8.0  ...                    Question
# 1109                         8.0  ...                      Answer
# 1110                         8.0  ...                    Question
# 1111                         8.0  ...                      Answer
# 1112                         8.0  ...                    Question
# 1113                         8.0  ...                      Answer
# 1114                         8.0  ...                    Question
# 1115                         8.0  ...                      Answer
# 1116                         8.0  ...                    Question
# 1117                         8.0  ...                      Answer
# 1118                         8.0  ...                    Question
# 1119                         8.0  ...                      Answer
# 1120                         8.0  ...                    Question
# 1121                         8.0  ...                      Answer
# 1122                         8.0  ...                    Question
# 1123                         8.0  ...                      Answer
# 1124                         8.0  ...                    Question
#
#       transcriptpersonid transcriptpersonname        proid companyofperson  \
# 1098            146141.0      Matthew Hedberg   30463897.0             NaN
# 1099            472231.0       Richard Herren  699029329.0             NaN
# 1100            146141.0      Matthew Hedberg   30463897.0             NaN
# 1101            472231.0       Richard Herren  699029329.0             NaN
# 1102            146141.0      Matthew Hedberg   30463897.0             NaN
# 1103            472231.0       Richard Herren  699029329.0             NaN
# 1104            146141.0      Matthew Hedberg   30463897.0             NaN
# 1105            472231.0       Richard Herren  699029329.0             NaN
# 1106            146141.0      Matthew Hedberg   30463897.0             NaN
# 1107            472231.0       Richard Herren  699029329.0             NaN
# 1108            146141.0      Matthew Hedberg   30463897.0             NaN
# 1109            472231.0       Richard Herren  699029329.0             NaN
# 1110            146141.0      Matthew Hedberg   30463897.0             NaN
# 1111            472231.0       Richard Herren  699029329.0             NaN
# 1112            146141.0      Matthew Hedberg   30463897.0             NaN
# 1113            472231.0       Richard Herren  699029329.0             NaN
# 1114            146141.0      Matthew Hedberg   30463897.0             NaN
# 1115            472231.0       Richard Herren  699029329.0             NaN
# 1116            146141.0      Matthew Hedberg   30463897.0             NaN
# 1117            472231.0       Richard Herren  699029329.0             NaN
# 1118            146141.0      Matthew Hedberg   30463897.0             NaN
# 1119            472231.0       Richard Herren  699029329.0             NaN
# 1120            146141.0      Matthew Hedberg   30463897.0             NaN
# 1121            472231.0       Richard Herren  699029329.0             NaN
# 1122            146141.0      Matthew Hedberg   30463897.0             NaN
# 1123            472231.0       Richard Herren  699029329.0             NaN
# 1124            146141.0      Matthew Hedberg   30463897.0             NaN
#
#       speakertypeid  speakertypename  \
# 1098            3.0         Analysts
# 1099            2.0       Executives
# 1100            3.0         Analysts
# 1101            2.0       Executives
# 1102            3.0         Analysts
# 1103            2.0       Executives
# 1104            3.0         Analysts
# 1105            2.0       Executives
# 1106            3.0         Analysts
# 1107            2.0       Executives
# 1108            3.0         Analysts
# 1109            2.0       Executives
# 1110            3.0         Analysts
# 1111            2.0       Executives
# 1112            3.0         Analysts
# 1113            2.0       Executives
# 1114            3.0         Analysts
# 1115            2.0       Executives
# 1116            3.0         Analysts
# 1117            2.0       Executives
# 1118            3.0         Analysts
# 1119            2.0       Executives
# 1120            3.0         Analysts
# 1121            2.0       Executives
# 1122            3.0         Analysts
# 1123            2.0       Executives
# 1124            3.0         Analysts
#
#                                    componenttextpreview  word_count  \
# 1098  Yes. Well, that's literally the next question....        42.0
# 1099  Yes. Enterprise was really strong for us in te...       488.0
# 1100  That's exciting. I wonder -- before we get int...        62.0
# 1101  Yes. We took up both the top line and the bott...        32.0
# 1102                          Yes. You're conservative.         3.0
# 1103  That's not my norm. What -- we took at the top...       274.0
# 1104  Yes. Yes. Yes. Back in our Autodesk days, the ...       115.0
# 1105  I think we are in a pretty unique position. An...       228.0
# 1106  Yes. When -- I guess if AI continues to ramp w...        80.0
# 1107  Yes. Of course, it could be. Now that target, ...        25.0
# 1108                            Yes, still a ways away.         5.0
# 1109  That target is less than 6 months old at this ...        27.0
# 1110  Yes. It certainly feels like whether it's AI a...        37.0
# 1111  I think to that point, Matt, there are several...       342.0
# 1112  Yes, let's pivot to Splunk. We had a call with...        87.0
# 1113  It's a standard play whenever there's an acqui...       235.0
# 1114  It's because it feels like it's not just AppD,...        19.0
# 1115                                    That's exactly.         3.0
# 1116  At Cisco. Talk about like how 1 plus 1 equals ...        14.0
# 1117  Yes. I think what everyone in cyber is trying ...       217.0
# 1118                                            Egress.         1.0
# 1119  Egress, there you go. But East-West track as w...        72.0
# 1120  What it feels like when you guys acquired AppD...        69.0
# 1121  100% it's going to be different than AppD. And...       369.0
# 1122  This is going fast, we only have 5 minutes to ...       126.0
# 1123  Yes. Let me start with the 2% metric. You're r...       306.0
# 1124  I lied. We don't have time for questions. We h...       131.0
#
#                                           componenttext
# 1098  Yes. Well, that's literally the next question....
# 1099  Yes. Enterprise was really strong for us in te...
# 1100  That's exciting. I wonder -- before we get int...
# 1101  Yes. We took up both the top line and the bott...
# 1102                          Yes. You're conservative.
# 1103  That's not my norm. What -- we took at the top...
# 1104  Yes. Yes. Yes. Back in our Autodesk days, the ...
# 1105  I think we are in a pretty unique position. An...
# 1106  Yes. When -- I guess if AI continues to ramp w...
# 1107  Yes. Of course, it could be. Now that target, ...
# 1108                            Yes, still a ways away.
# 1109  That target is less than 6 months old at this ...
# 1110  Yes. It certainly feels like whether it's AI a...
# 1111  I think to that point, Matt, there are several...
# 1112  Yes, let's pivot to Splunk. We had a call with...
# 1113  It's a standard play whenever there's an acqui...
# 1114  It's because it feels like it's not just AppD,...
# 1115                                    That's exactly.
# 1116  At Cisco. Talk about like how 1 plus 1 equals ...
# 1117  Yes. I think what everyone in cyber is trying ...
# 1118                                            Egress.
# 1119  Egress, there you go. But East-West track as w...
# 1120  What it feels like when you guys acquired AppD...
# 1121  100% it's going to be different than AppD. And...
# 1122  This is going fast, we only have 5 minutes to ...
# 1123  Yes. Let me start with the 2% metric. You're r...
# 1124  I lied. We don't have time for questions. We h...
#
# [27 rows x 29 columns]

# %%
processed_df = df.copy()

results = processed_df.apply(process_row, axis=1)
processed_df[["is_data_or_ai", "representative_quotes", "quantitative_summary", "qualitative_summary"]] = results

processed_df.head()
# Out:
#      companyid      keydevid  transcriptid  \
# 1098     19691  1.904126e+09     3318005.0
# 1099     19691  1.904126e+09     3318005.0
# 1100     19691  1.904126e+09     3318005.0
# 1101     19691  1.904126e+09     3318005.0
# 1102     19691  1.904126e+09     3318005.0
#
#                                                headline mostimportantdateutc  \
# 1098  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1099  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1100  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1101  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
# 1102  Cisco Systems, Inc. Presents at 2024 RBC Capit...           2024-11-20
#
#      mostimportanttimeutc  keydeveventtypeid  \
# 1098             16:20:00               51.0
# 1099             16:20:00               51.0
# 1100             16:20:00               51.0
# 1101             16:20:00               51.0
# 1102             16:20:00               51.0
#
#                    keydeveventtypename          companyname  \
# 1098  Company Conference Presentations  Cisco Systems, Inc.
# 1099  Company Conference Presentations  Cisco Systems, Inc.
# 1100  Company Conference Presentations  Cisco Systems, Inc.
# 1101  Company Conference Presentations  Cisco Systems, Inc.
# 1102  Company Conference Presentations  Cisco Systems, Inc.
#
#       transcriptcollectiontypeid  ... companyofperson  speakertypeid  \
# 1098                         8.0  ...             NaN            3.0
# 1099                         8.0  ...             NaN            2.0
# 1100                         8.0  ...             NaN            3.0
# 1101                         8.0  ...             NaN            2.0
# 1102                         8.0  ...             NaN            3.0
#
#      speakertypename                               componenttextpreview  \
# 1098        Analysts  Yes. Well, that's literally the next question....
# 1099      Executives  Yes. Enterprise was really strong for us in te...
# 1100        Analysts  That's exciting. I wonder -- before we get int...
# 1101      Executives  Yes. We took up both the top line and the bott...
# 1102        Analysts                          Yes. You're conservative.
#
#      word_count                                      componenttext  \
# 1098       42.0  Yes. Well, that's literally the next question....
# 1099      488.0  Yes. Enterprise was really strong for us in te...
# 1100       62.0  That's exciting. I wonder -- before we get int...
# 1101       32.0  Yes. We took up both the top line and the bott...
# 1102        3.0                          Yes. You're conservative.
#
#       is_data_or_ai                              representative_quotes  \
# 1098              0
# 1099              1  "what's driving that demand is companies looki...
# 1100              0
# 1101              0
# 1102              0
#
#                                    quantitative_summary  \
# 1098
# 1099  "Company handles about 1.5 million customer su...
# 1100
# 1101
# 1102
#
#                                     qualitative_summary
# 1098
# 1099  "Enterprise AI adoption is driving increased n...
# 1100
# 1101
# 1102
#
# [5 rows x 33 columns]

# %%
output_filename = datetime.now().strftime("processed_transcripts_%Y%m%d_%H%M%S.csv")
output_path = f"output/{output_filename}"
processed_df.to_csv(output_path, index=False)
